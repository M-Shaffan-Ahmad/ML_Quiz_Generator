# %% [markdown]
# # Experiments
#
# This notebook is the rubric-facing experiment log. The main repeatable experiments live in `src/`, while older scratch/versioned notebooks are archived under `bts/notebooks/versions_project/` to keep the submitted project structure clean.
#
# Key commands:
#
# - `../venv/bin/python src/model_a_train.py --target classical`
# - `../venv/bin/python src/model_a_train.py --target generator`
# - `../venv/bin/python src/model_a_train.py --target unsupervised`
# - `../venv/bin/python src/model_b_train.py`
# - `../venv/bin/python src/evaluate.py --target model-a-classical`
